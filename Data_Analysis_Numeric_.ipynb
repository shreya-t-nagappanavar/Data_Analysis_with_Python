# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-t-nagappanavar/Data_Analysis_with_Python/blob/main/Data_Analysis_Numeric_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis - Numeric

# %%
import pandas as pd

# %%
data1 = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
data = data1.head(100)

# %%
data.dropna()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# ..        ...       ...                 ...          ...             ...
# 95    -115.58     32.81                 5.0        805.0           143.0
# 96    -115.58     32.81                10.0       1088.0           203.0
# 97    -115.58     32.79                14.0       1687.0           507.0
# 98    -115.58     32.78                 5.0       2494.0           414.0
# 99    -115.59     32.85                20.0       1608.0           274.0
#
#     population  households  median_income  median_house_value
# ...

# %% [markdown]
# **1) Finding average rating**

# %%
data['latitude']
# Out:
# 0     34.19
# 1     34.40
# 2     33.69
# 3     33.64
# 4     33.57
#       ...
# 95    32.81
# 96    32.81
# 97    32.79
# 98    32.78
# 99    32.85
# Name: latitude, Length: 100, dtype: float64

# %%
int(sum(data['latitude']))/100
# Out:
# 33.14

# %%
float(str(int(sum(data['latitude']))/100))
# Out:
# 33.14

# %%
s = 0
for i in data['latitude']:
    s += i
s = int(s)
print(s)
# Out:
# 3314

# %%
int(sum(data['latitude']))
# Out:
# 3314

# %%
len(data['latitude'])
# Out:
# 100

# %%
int(sum(data['latitude']))/len(data['latitude'])
# Out:
# 33.14

# %%
print("Avarage rating of the latitude = " + str(int(sum(data['latitude']))/len(data['latitude'])))
# Out:
# Avarage rating of the latitude = 33.14

# %% [markdown]
# **2) How many housing_median_age are there in total_rooms**

# %%
data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# ..        ...       ...                 ...          ...             ...
# 95    -115.58     32.81                 5.0        805.0           143.0
# 96    -115.58     32.81                10.0       1088.0           203.0
# 97    -115.58     32.79                14.0       1687.0           507.0
# 98    -115.58     32.78                 5.0       2494.0           414.0
# 99    -115.59     32.85                20.0       1608.0           274.0
#
#     population  households  median_income  median_house_value
# ...

# %%
c = 0

for i in data['total_rooms']:
  if (i == 805.0):
     c += 1
print("these may rooms availble = " + str(c))
# Out:
# these may rooms availble = 1

# %%
c = 0

for i in data['total_rooms']:
  if (i >= 805.0 and i <= 2000):
     c += 1
print("these may rooms availble = " + str(c))
# Out:
# these may rooms availble = 62
